# %% [markdown]
# <a href="https://colab.research.google.com/github/Rumaisa30/Reaction-Time-Analysis/blob/main/Rumaisa_Siddiqui_Independent_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exploring Representation and Variability in a Cognitive Reaction Time Dataset**
#
# My Goal: This project analyzes a publicly available cognitive reaction time dataset to explore demographic representation, missing data patterns, and variability performance.
#
# My Research Questions:
#
# 1.   How are demographics groups represented in the dataset?
# 2.   Is missing data distributed evenly amongst all groups?
# 3. How does the reaction time performance vary between demographics?
#
# Dataset: Reaction Times to Audio/Visual Stimuli
#
# Tools:
# - Python
# - pandas
# - numpy
# - matplotlib
# - Google Colab

# %%
# Import necessary library
import pandas as pd  # using pandas for data manipulation and analysis

import matplotlib.pyplot as plt
#Upload the CSV into a DataFrame
data = pd.read_csv("Reaction_Times_to_Audio_and_Visual_Stimuli_1100_90.csv")

#drop unnecessary index columns
columns_to_drop = [col for col in ['Unnamed: 0', 'X'] if col in data.columns]
data = data.drop(columns=columns_to_drop)

data.head()

#Count how many participants are in each group (Musician vs Non-Musician)
data['Group'].value_counts()

#count missing values in each column
data.isnull().sum()

#check missing values by group
data.groupby('Group').agg(lambda x: x.isnull().sum())

#removes missing data
data_clean = data.dropna(subset=["ResponseTime"])

print("Reaction Time Analysis by Stimulus Type:\n")
#Summary table
summary_df = pd.DataFrame({
    "Stimulus": means['Stimulus'].str.capitalize(),   # proper column
    "Mean RT (ms)": means['ResponseTime'].round(2),
    "SD (ms)": stds['ResponseTime'].round(2)
})

print("Summary Table:\n")
display(summary_df)

#Visualization
data_clean.boxplot(column="ResponseTime", by="Stimulus")
plt.title("Reaction Time by Stimulus Type")
plt.suptitle("") #removes automatic subtitle
plt.xlabel("Stimulus Type")
plt.ylabel("Reaction Time (ms)")
plt.show()
# Out:
# Reaction Time Analysis by Stimulus Type:
#
# Summary Table:
#    Stimulus  Mean RT (ms)  SD (ms)
# 0  Auditory        215.86    86.88
# 1    Visual        288.82    60.42
